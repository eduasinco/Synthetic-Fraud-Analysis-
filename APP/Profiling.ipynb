# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import os
from datetime import datetime 
from sklearn.metrics import roc_auc_score as auc 
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
# %matplotlib inline

df = pd.read_csv('/Users/eduardorodriguez/Desktop/TFM/DATA/banksim/banksim.csv')
df.head()
# Out:
#    step       customer  age gender zipcodeOri       merchant zipMerchant  \
# 0     0  'C1093826151'  '4'    'M'    '28007'   'M348934600'     '28007'
# 1     0   'C352968107'  '2'    'M'    '28007'   'M348934600'     '28007'
# 2     0  'C2054744914'  '4'    'F'    '28007'  'M1823072687'     '28007'
# 3     0  'C1760612790'  '3'    'M'    '28007'   'M348934600'     '28007'
# 4     0   'C757503768'  '5'    'M'    '28007'   'M348934600'     '28007'
#
#               category  amount  fraud
# 0  'es_transportation'    4.55      0
# 1  'es_transportation'   39.68      0
# 2  'es_transportation'   26.89      0
# 3  'es_transportation'   17.25      0
# 4  'es_transportation'   35.72      0

# %%
import pandas_profiling
profile = pandas_profiling.ProfileReport(df)
profile.to_file(outputfile="/Users/eduardorodriguez/Desktop/TFM/DATA/banksim/banksim_profile.html")
# Out:
# /Users/eduardorodriguez/anaconda2/envs/TFM/lib/python3.6/site-packages/pandas_profiling/plot.py:15: UserWarning:
# This call to matplotlib.use() has no effect because the backend has already
# been chosen; matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
# The backend was *originally* set to 'module://ipykernel.pylab.backend_inline' by the following code:
#   File "/Users/eduardorodriguez/anaconda2/envs/TFM/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/Users/eduardorodriguez/anaconda2/envs/TFM/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/Users/eduardorodriguez/anaconda2/envs/TFM/lib/python3.6/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/Users/eduardorodriguez/anaconda2/envs/TFM/lib/python3.6/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/Users/eduardorodriguez/anaconda2/envs/TFM/lib/python3.6/site-packages/ipykernel/kernelapp.py", line 486, in start
#     self.io_loop.start()
#   File "/Users/eduardorodriguez/anaconda2/envs/TFM/lib/python3.6/site-packages/tornado/platform/asyncio.py", line 127, in start
#     self.asyncio_loop.run_forever()
#   File "/Users/eduardorodriguez/anaconda2/envs/TFM/lib/python3.6/asyncio/base_events.py", line 422, in run_forever
#     self._run_once()
#   File "/Users/eduardorodriguez/anaconda2/envs/TFM/lib/python3.6/asyncio/base_events.py", line 1432, in _run_once
#     handle._run()
#   File "/Users/eduardorodriguez/anaconda2/envs/TFM/lib/python3.6/asyncio/events.py", line 145, in _run
#     self._callback(*self._args)
#   File "/Users/eduardorodriguez/anaconda2/envs/TFM/lib/python3.6/site-packages/tornado/platform/asyncio.py", line 117, in _handle_events
#     handler_func(fileobj, events)
#   File "/Users/eduardorodriguez/anaconda2/envs/TFM/lib/python3.6/site-packages/tornado/stack_context.py", line 276, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/Users/eduardorodriguez/anaconda2/envs/TFM/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 450, in _handle_events
#     self._handle_recv()
#   File "/Users/eduardorodriguez/anaconda2/envs/TFM/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 480, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/Users/eduardorodriguez/anaconda2/envs/TFM/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 432, in _run_callback
#     callback(*args, **kwargs)
#   File "/Users/eduardorodriguez/anaconda2/envs/TFM/lib/python3.6/site-packages/tornado/stack_context.py", line 276, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/Users/eduardorodriguez/anaconda2/envs/TFM/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/Users/eduardorodriguez/anaconda2/envs/TFM/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 233, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/Users/eduardorodriguez/anaconda2/envs/TFM/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "/Users/eduardorodriguez/anaconda2/envs/TFM/lib/python3.6/site-packages/ipykernel/ipkernel.py", line 208, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/Users/eduardorodriguez/anaconda2/envs/TFM/lib/python3.6/site-packages/ipykernel/zmqshell.py", line 537, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/Users/eduardorodriguez/anaconda2/envs/TFM/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2662, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "/Users/eduardorodriguez/anaconda2/envs/TFM/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2785, in _run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/Users/eduardorodriguez/anaconda2/envs/TFM/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2903, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/Users/eduardorodriguez/anaconda2/envs/TFM/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2963, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-2-9a62fc63854f>", line 9, in <module>
#     get_ipython().run_line_magic('matplotlib', 'inline')
#   File "/Users/eduardorodriguez/anaconda2/envs/TFM/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2131, in run_line_magic
#     result = fn(*args,**kwargs)
#   File "<decorator-gen-107>", line 2, in matplotlib
#   File "/Users/eduardorodriguez/anaconda2/envs/TFM/lib/python3.6/site-packages/IPython/core/magic.py", line 187, in <lambda>
#     call = lambda f, *a, **k: f(*a, **k)
#   File "/Users/eduardorodriguez/anaconda2/envs/TFM/lib/python3.6/site-packages/IPython/core/magics/pylab.py", line 99, in matplotlib
#     gui, backend = self.shell.enable_matplotlib(args.gui)
#   File "/Users/eduardorodriguez/anaconda2/envs/TFM/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3051, in enable_matplotlib
#     pt.activate_matplotlib(backend)
#   File "/Users/eduardorodriguez/anaconda2/envs/TFM/lib/python3.6/site-packages/IPython/core/pylabtools.py", line 311, in activate_matplotlib
#     matplotlib.pyplot.switch_backend(backend)
#   File "/Users/eduardorodriguez/anaconda2/envs/TFM/lib/python3.6/site-packages/matplotlib/pyplot.py", line 231, in switch_backend
#     matplotlib.use(newbackend, warn=False, force=True)
#   File "/Users/eduardorodriguez/anaconda2/envs/TFM/lib/python3.6/site-packages/matplotlib/__init__.py", line 1410, in use
#     reload(sys.modules['matplotlib.backends'])
#   File "/Users/eduardorodriguez/anaconda2/envs/TFM/lib/python3.6/importlib/__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "/Users/eduardorodriguez/anaconda2/envs/TFM/lib/python3.6/site-packages/matplotlib/backends/__init__.py", line 16, in <module>
#     line for line in traceback.format_stack()
#
#
#   matplotlib.use(BACKEND)
