# %%
auc_score = [0.8958092027742083, 0.8979613848427012, 0.5218077855383412, 0.4973184630483559, 0.7725274094273846, ]
f1_score = [0.3191373686118159, 0.3207683943457774, 0.03570134106560348, 0.001238390092879257, 0.6672199170124481, ]
train_times = [2.99, 1.69, 3.39, 3.95, 0.307, ]
prediction_times = [26.5, 2.31, 3.93, 51.8, 1.08 , 0.07747]
algorithm = ['IForest', 'KMeans', 'LOF', 'OneClassSVM', 'KNN', 'RBM']

# %%
import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt
 
plt.bar(algorithm, auc_score, align='center')
plt.xticks(algorithm, algorithm)
plt.ylabel('auc/f1')
plt.title('AUC y F1')

plt.bar(algorithm, f1_score, align='center')
plt.xticks(algorithm, algorithm)

plt.show()

# %%
plt.bar(algorithm, prediction_times, align='center')
plt.xticks(algorithm, algorithm)
 
plt.bar(algorithm, train_times, align='center')
plt.xticks(algorithm, algorithm)
plt.ylabel('Seconds')
plt.title('Train and Prediction Times')

plt.show()
